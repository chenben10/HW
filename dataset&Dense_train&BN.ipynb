# %% [markdown]
# <a href="https://colab.research.google.com/github/chenben10/HW/blob/master/dataset%26Dense_train%26BN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
import numpy as np
import random 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#dataset
dataset = 100000

np.random.seed(50)

#產生dataset列 X2行的0~1隨機數字
D=np.random.random(size=(dataset,2))
#velocity 假設初速
V=D[:,0]*100
#theta 假設角度
theta=D[:,1]*90
theta

print(V)

#初速平方
v2=pow(V,2)

#sin theta 平方
sin2=pow(np.sin(np.deg2rad(theta)),2)

#sin theta乘 cos theta
sincos=np.multiply(np.sin(np.deg2rad(theta)),np.cos(np.deg2rad(theta)))


#拋物線公式計算Max H & R
H=np.multiply(v2,sin2)/2/9.8
R=2*np.multiply(v2,sincos)/9.8

#將數據重新reshaape
V=np.reshape(V,(dataset,-1))
theta=np.reshape(theta,(dataset,-1))
R=np.reshape(R,(dataset,-1))
H=np.reshape(H,(dataset,-1))


#將數據append一起
dataset1=np.append(V,theta, axis=1)
dataset1=np.append(dataset1,R, axis=1)
dataset1=np.append(dataset1,H, axis=1)
print("    Velocity   ,  theta   ,     Max R ,      Max H")
print(dataset1)
# Out:
# [49.46016455 25.54739238 37.73150977 ... 37.20660925 74.8116243
#  28.25759976]
#     Velocity   ,  theta   ,     Max R ,      Max H
# [[ 49.46016455  20.5274794  163.94822238  15.34684174]
#  [ 25.54739238  35.66969188  63.09782844  11.32244925]
#  [ 37.73150977  89.69168071   1.56344267  72.63395941]
#  ...
#  [ 37.20660925  80.89689707  44.13444777  68.86126085]
#  [ 74.8116243   64.06090058 449.2844039  230.91500595]
#  [ 28.25759976  66.47708834  59.63422266  34.24987036]]

# %%
fig1 = plt.figure()
ax = plt.axes(projection='3d')

# 將random數據分成三種顏色繪製
ax.scatter(V[:3000], theta[:3000], R[:3000], c='r',alpha=0.3)  # 繪製數據點
ax.scatter(V[3000:6000], theta[3000:6000], R[3000:6000], c='g',alpha=0.2)
ax.scatter(V[6000:10000], theta[6000:10000], R[6000:10000], c='b',alpha=0.05)
ax.set_zlabel('Max R')  #坐標軸
ax.set_ylabel('theta')
ax.set_xlabel('V')
ax.view_init(45, 30)
plt.savefig('MaxRdata.png',dpi=150)

fig2 = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter(V[:3000], theta[:3000], H[:3000], c='r',alpha=0.05)  # 繪製數據點
ax.scatter(V[3000:6000], theta[3000:6000], H[3000:6000], c='g',alpha=0.1)
ax.scatter(V[6000:10000], theta[6000:10000], H[6000:10000], c='b',alpha=0.05)
ax.set_zlabel('Max H')  #坐標軸
ax.set_ylabel('theta')
ax.set_xlabel('V')
ax.view_init(45, -80)
plt.savefig('MaxHdata.png',dpi=150)

# %%
#X為已知初速及仰角 Y為結果之Max R&H
X=dataset1[:,:2]
Y=dataset1[:,2:4]

traindata=0.9*dataset # 取資料點當中前 90% 筆資料當作 training data
testdata=0.1*dataset # 取資料點當中，後 10% 筆資料當作 testing data

# 建立 trainig 與 testing data
X_train, Y_train = X[:int(traindata)], Y[:int(traindata)]
X_test, Y_test = X[int(traindata):], Y[int(traindata):]

# %%
#建模
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(16, input_dim=2,kernel_initializer='normal', activation=tf.nn.relu,name='Input_Layer'),
    tf.keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True,name='BN_Layer1'),
    tf.keras.layers.Dense(64, activation=tf.nn.relu,name='hidden_Layer2'),
    tf.keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True,name='BN_Layer2'),
    tf.keras.layers.Dense(32, activation=tf.nn.relu,name='hidden_Layer3'),
    tf.keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True,name='BN_Layer3'),
    tf.keras.layers.Dense(2,name='output_Layer')])



model.compile(optimizer='adam',loss='mse',metrics=['accuracy'])             

    
print( "Training ------------")
# Another way to train the model
model.fit(X_train, Y_train, epochs=40, batch_size=32, validation_split=0.1)



print( "\nTesting ------------")
# Evaluate the model with the metrics we defined earlier
score = model.evaluate(X_test, Y_test, verbose=0)

## loss, accuracy = model.evaluate(X_test, Y_test)

print( "test loss: {}".format(score[0])) #loss
print( "test accuracy: {}".format(score[1])) #accuracy
# Out:
# Training ------------
# Train on 81000 samples, validate on 9000 samples
# Epoch 1/40
# 81000/81000 [==============================] - 6s 70us/sample - loss: 24118.3818 - acc: 0.6578 - val_loss: 2417.9894 - val_acc: 0.9186
# Epoch 2/40
# 81000/81000 [==============================] - 5s 67us/sample - loss: 2330.6859 - acc: 0.8959 - val_loss: 320.6066 - val_acc: 0.9144
# Epoch 3/40
# 81000/81000 [==============================] - 5s 67us/sample - loss: 1888.0563 - acc: 0.8883 - val_loss: 537.5356 - val_acc: 0.9624
# Epoch 4/40
# 81000/81000 [==============================] - 6s 75us/sample - loss: 1817.5296 - acc: 0.8843 - val_loss: 311.4194 - val_acc: 0.8370
# Epoch 5/40
# 81000/81000 [==============================] - 6s 68us/sample - loss: 1789.3107 - acc: 0.8817 - val_loss: 566.8540 - val_acc: 0.8459
# Epoch 6/40
# 81000/81000 [==============================] - 5s 65us/sample - loss: 1708.6993 - acc: 0.8797 - val_loss: 244.8524 - val_acc: 0.9763
# Epoch 7/40
# 81000/81000 [==============================] - 5s 67us/sample - loss: 1630.2814 - acc: 0.8768 - val_loss: 445.8797 - val_acc: 0.9502
# Epoch 8/40
# 81000/81000 [==============================] - 5s 66us/sample - loss: 1611.8469 - acc: 0.8764 - val_loss: 517.5247 - val_acc: 0.9518
# Epoch 9/40
# 81000/81000 [==============================] - 5s 67us/sample - loss: 1553.6137 - acc: 0.8740 - val_loss: 376.8384 - val_acc: 0.9357
# Epoch 10/40
# 81000/81000 [==============================] - 5s 65us/sample - loss: 1569.8395 - acc: 0.8730 - val_loss: 343.4250 - val_acc: 0.9206
# Epoch 11/40
# 81000/81000 [==============================] - 6s 73us/sample - loss: 1521.7681 - acc: 0.8744 - val_loss: 430.6561 - val_acc: 0.9324
# Epoch 12/40
# 81000/81000 [==============================] - 6s 74us/sample - loss: 1557.9410 - acc: 0.8720 - val_loss: 200.5397 - val_acc: 0.9498
# Epoch 13/40
# 81000/81000 [==============================] - 5s 64us/sample - loss: 1549.6452 - acc: 0.8721 - val_loss: 261.4482 - val_acc: 0.9682
# Epoch 14/40
# 81000/81000 [==============================] - 5s 65us/sample - loss: 1525.2727 - acc: 0.8750 - val_loss: 579.7273 - val_acc: 0.9457
# Epoch 15/40
# 81000/81000 [==============================] - 5s 64us/sample - loss: 1499.1958 - acc: 0.8760 - val_loss: 152.9007 - val_acc: 0.9658
# Epoch 16/40
# 81000/81000 [==============================] - 5s 63us/sample - loss: 1529.6064 - acc: 0.8736 - val_loss: 543.3280 - val_acc: 0.9323
# Epoch 17/40
# 81000/81000 [==============================] - 5s 63us/sample - loss: 1490.1649 - acc: 0.8734 - val_loss: 77.7347 - val_acc: 0.9477
# Epoch 18/40
# 81000/81000 [==============================] - 5s 63us/sample - loss: 1468.5241 - acc: 0.8713 - val_loss: 491.6483 - val_acc: 0.8532
# Epoch 19/40
# 81000/81000 [==============================] - 5s 63us/sample - loss: 1408.1404 - acc: 0.8748 - val_loss: 146.2946 - val_acc: 0.9137
# Epoch 20/40
# 81000/81000 [==============================] - 5s 64us/sample - loss: 1417.6183 - acc: 0.8710 - val_loss: 204.0345 - val_acc: 0.9223
# Epoch 21/40
# 81000/81000 [==============================] - 5s 63us/sample - loss: 1415.3332 - acc: 0.8706 - val_loss: 103.1864 - val_acc: 0.9349
# Epoch 22/40
# 81000/81000 [==============================] - 5s 63us/sample - loss: 1407.9979 - acc: 0.8721 - val_loss: 169.8004 - val_acc: 0.9431
# Epoch 23/40
# 81000/81000 [==============================] - 5s 62us/sample - loss: 1453.5357 - acc: 0.8700 - val_loss: 100.1145 - val_acc: 0.9209
# Epoch 24/40
# 81000/81000 [==============================] - 5s 62us/sample - loss: 1447.7266 - acc: 0.8711 - val_loss: 347.4467 - val_acc: 0.9510
# Epoch 25/40
# 81000/81000 [==============================] - 5s 62us/sample - loss: 1451.3973 - acc: 0.8713 - val_loss: 875.0585 - val_acc: 0.8558
# Epoch 26/40
# 81000/81000 [==============================] - 5s 62us/sample - loss: 1341.9996 - acc: 0.8724 - val_loss: 291.7933 - val_acc: 0.9218
# Epoch 27/40
# 81000/81000 [==============================] - 5s 62us/sample - loss: 1400.5663 - acc: 0.8695 - val_loss: 668.1690 - val_acc: 0.8103
# Epoch 28/40
# 81000/81000 [==============================] - 5s 63us/sample - loss: 1447.3169 - acc: 0.8690 - val_loss: 516.0755 - val_acc: 0.9216
# Epoch 29/40
# 81000/81000 [==============================] - 5s 62us/sample - loss: 1438.3534 - acc: 0.8712 - val_loss: 155.6193 - val_acc: 0.9363
# Epoch 30/40
# 81000/81000 [==============================] - 5s 62us/sample - loss: 1356.3385 - acc: 0.8700 - val_loss: 277.1661 - val_acc: 0.9187
# Epoch 31/40
# 81000/81000 [==============================] - 5s 62us/sample - loss: 1417.6624 - acc: 0.8682 - val_loss: 404.3468 - val_acc: 0.9454
# Epoch 32/40
# 81000/81000 [==============================] - 5s 62us/sample - loss: 1365.0616 - acc: 0.8716 - val_loss: 79.4593 - val_acc: 0.9659
# Epoch 33/40
# 81000/81000 [==============================] - 5s 62us/sample - loss: 1387.9388 - acc: 0.8689 - val_loss: 350.2440 - val_acc: 0.8808
# Epoch 34/40
# 81000/81000 [==============================] - 5s 62us/sample - loss: 1376.3853 - acc: 0.8685 - val_loss: 260.4542 - val_acc: 0.9051
# Epoch 35/40
# 81000/81000 [==============================] - 5s 63us/sample - loss: 1365.6437 - acc: 0.8709 - val_loss: 109.4086 - val_acc: 0.9433
# Epoch 36/40
# 81000/81000 [==============================] - 5s 63us/sample - loss: 1368.9437 - acc: 0.8691 - val_loss: 323.2547 - val_acc: 0.8876
# Epoch 37/40
# 81000/81000 [==============================] - 5s 63us/sample - loss: 1345.1620 - acc: 0.8675 - val_loss: 368.6042 - val_acc: 0.9510
# Epoch 38/40
# 81000/81000 [==============================] - 5s 63us/sample - loss: 1421.4126 - acc: 0.8706 - val_loss: 78.1561 - val_acc: 0.9159
# Epoch 39/40
# 81000/81000 [==============================] - 5s 63us/sample - loss: 1372.1508 - acc: 0.8699 - val_loss: 499.2916 - val_acc: 0.9468
# Epoch 40/40
# 81000/81000 [==============================] - 5s 62us/sample - loss: 1360.6690 - acc: 0.8654 - val_loss: 259.6795 - val_acc: 0.9348
#
# Testing ------------
# test loss: 262.91351225585936
# test accuracy: 0.9368000030517578

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_Layer (Dense)          (None, 16)                48
# _________________________________________________________________
# BN_Layer1 (BatchNormalizatio (None, 16)                64
# _________________________________________________________________
# hidden_Layer2 (Dense)        (None, 64)                1088
# _________________________________________________________________
# BN_Layer2 (BatchNormalizatio (None, 64)                256
# _________________________________________________________________
# hidden_Layer3 (Dense)        (None, 32)                2080
# _________________________________________________________________
# BN_Layer3 (BatchNormalizatio (None, 32)                128
# _________________________________________________________________
# output_Layer (Dense)         (None, 2)                 66
# =================================================================
# Total params: 3,730
# Trainable params: 3,506
# Non-trainable params: 224
# _________________________________________________________________
